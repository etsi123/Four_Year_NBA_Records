# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
team_names = ['atlanta_hawks','boston_celtics','brooklyn_nets','charlotte_hornets','chicago_bulls',\
              'cleveland_cavaliers','dallas_mavericks','denver_nuggets','detroit_pistons','golden_state_warriors',\
             'houston_rockets','indiana_pacers','los_angeles_clippers','los_angeles_lakers','memphis_grizzlies',\
             'miami_heat','milwaukee_bucks','minnesota_timberwolves','new_york_knicks','oklahoma_city_thunder',\
             'orlando_magic','philadelphia_76ers','phoenix_suns','portland_trailblazers','sacramento_kings',\
             'san_antonio_spurs','toronto_raptors','utah_jazz','washington_wizards']

# %%
#Define what makes a good team. Somewhat arbitrary cutoffs but based on 
#statistics of p(winning championship | X wins). 
def historical_ranking_classifier(value):
    if value >= 65:
        return "Legendary"
    elif value >=60 and value<65: 
        return "Historically Great Contenders"
    elif value >= 55 and value<60: 
        return "Serious contenders"
    elif value >= 50 and value<55: 
        return "Good Contenders"
    elif value >= 40 and value < 50: 
        return "Borderline Playoff Team"
    else: 
        return "Poor"

# %%
#Function to get team records
def get_team_records(team_names): 
    df = pd.DataFrame({})
    for team in team_names: 
        url = 'https://www.landofbasketball.com/teams/records_' + team + '.htm'
        data = requests.get(url).text
        soup = BeautifulSoup(data, 'html.parser')
        tables = soup.find_all('table')  
        try: 
            temp = pd.read_html(str(tables),skiprows=2)[1]
        except: 
            temp = pd.read_html(str(tables),skiprows=2)[0]
        temp.columns = ['Season','Team','Record','Win%','Standing','Conf','a','b','c']
        temp = temp[['Season','Team','Record']]   
        df = pd.concat([df,temp])   
    return df

# %%
df = get_team_records(team_names)
df.head()
# Out:
#     Season   Team Record
# 0  2022-23  Hawks  13-10
# 1  2021-22  Hawks  43-39
# 2  2020-21  Hawks  41-31
# 3  2019-20  Hawks  20-47
# 4  2018-19  Hawks  29-53

# %%
#Old school teams. 
drop_list = ['Braves','Blackhawks','Zephyrs','Packers']
for drop in drop_list: 
    df = df[df['Team']!=drop]

# %%
df = df.sort_values(['Team','Season']).reset_index(drop=True)
df.head()
# Out:
#     Season   Team Record
# 0  1963-64  76ers  34-46
# 1  1964-65  76ers  40-40
# 2  1965-66  76ers  55-25
# 3  1966-67  76ers  68-13
# 4  1967-68  76ers  62-20

# %%
#Remove this season since it isn't complete! 
df = df[df['Season']!='2022-2023']

# %%
#Coonvert to single number representation (2012-2013 season will be represented as the 2013 season)
temp = df['Season'].str.split('-', expand=True)
temp.columns = ['Season','Year_p2']
temp['Season'] = temp['Season'].astype(int) + 1
temp = temp[['Season']]
df = df.drop(['Season'],axis=1)
df = pd.concat([temp,df],axis=1)
df.head()
# Out:
#    Season   Team Record
# 0    1964  76ers  34-46
# 1    1965  76ers  40-40
# 2    1966  76ers  55-25
# 3    1967  76ers  68-13
# 4    1968  76ers  62-20

# %%
#82 game NBA seasons.
df = df[df['Season'] > 1970]

# %%
#Convert record into just wins since W+L = 82
temp = df['Record'].str.split('-', expand=True)
temp.columns = ['Wins','Loss']
df = pd.concat([df,temp],axis=1)
df = df[['Team','Season','Wins']]
df.head()
# Out:
#      Team  Season Wins
# 7   76ers    1971   47
# 8   76ers    1972   30
# 9   76ers    1973    9
# 10  76ers    1974   25
# 11  76ers    1975   34

# %%
#Compute the rolling sums over 4 year increments. 
df_results = pd.DataFrame(df.groupby('Team')['Wins'].rolling(4).sum()).reset_index().drop(['level_1'],axis=1)
df_results.head()
# Out:
#     Team   Wins
# 0  76ers    NaN
# 1  76ers    NaN
# 2  76ers    NaN
# 3  76ers  111.0
# 4  76ers   98.0

# %%
#Remove the missing data constructed.
df_results = df_results.dropna()
df_results.head()
# Out:
#     Team   Wins
# 3  76ers  111.0
# 4  76ers   98.0
# 5  76ers  114.0
# 6  76ers  155.0
# 7  76ers  185.0

# %%
#Construct the final pandas dataframe. Loop through the teams and update year info. 
final = pd.DataFrame({})
for team in df_results.Team.unique().tolist(): 
    temp = df[df['Team'] == team]
    
    a = temp.Season.min()
    years = []
    era_label = []
    for i in range(temp.shape[0]): 
        r = str(a) + ' - ' + str(a+4-1)
        years.append(r)
        a = a + 1
        if a>=1970 and a<=1973: 
            era_label.append('The early 70s ' + team)
        elif a>=1974 and a<=1977: 
            era_label.append('The mid 70s ' + team)
        elif a>=1978 and a<=1979: 
            era_label.append('The late 70s ' + team)
        elif a>=1980 and a<=1983: 
            era_label.append('The early 80s ' + team)
        elif a>=1984 and a<=1987: 
            era_label.append('The mid 80s ' + team)
        elif a>=1988 and a<=1989: 
            era_label.append('The late 80s ' + team)            
        elif a>=1990 and a<=1993: 
            era_label.append('The early 90s ' + team)
        elif a>=1994 and a<=1997: 
            era_label.append('The mid 90s ' + team)
        elif a>=1998 and a<=1999: 
            era_label.append('The late 90s ' + team)          
        elif a>=2000 and a<=2003: 
            era_label.append('The early 2000s ' + team)
        elif a>=2004 and a<=2007: 
            era_label.append('The mid 2000s ' + team)
        elif a>=2008 and a<=2009: 
            era_label.append('The late 2000s ' + team)  
            
        elif a>=2010 and a<=2013: 
            era_label.append('The early 2010s ' + team)
        elif a>=2014 and a<=2017: 
            era_label.append('The mid 2010s ' + team)
        elif a>=2018 and a<=2019: 
            era_label.append('The late 2010s ' + team) 
        else: 
            era_label.append('The early 2020s ' + team)
        
            
    t = pd.DataFrame({'Year Range':years,'Era':era_label})
    #t = pd.DataFrame([years,era_label],columns = ['Year Range','Era Label'])
    
    temp = df_results[df_results['Team'] == team]
    temp = pd.concat([temp.reset_index(drop=True),t.reset_index(drop=True)],axis=1)
    final = pd.concat([final.reset_index(drop=True),temp.reset_index(drop=True)])

# %%
final = final.dropna()
final = final.reset_index(drop=True)
final.head()
# Out:
#     Team   Wins   Year Range                  Era
# 0  76ers  111.0  1971 - 1974  The early 70s 76ers
# 1  76ers   98.0  1972 - 1975  The early 70s 76ers
# 2  76ers  114.0  1973 - 1976    The mid 70s 76ers
# 3  76ers  155.0  1974 - 1977    The mid 70s 76ers
# 4  76ers  185.0  1975 - 1978    The mid 70s 76ers

# %%
final.Wins.hist()
# Out:
# <AxesSubplot:>

# %%
final = final.sort_values(['Wins'],ascending=False)
final.head()
# Out:
#           Team   Wins   Year Range                     Era
# 1238  Warriors  265.0  2015 - 2018  The mid 2010s Warriors
# 1237  Warriors  258.0  2014 - 2017  The mid 2010s Warriors
# 1239  Warriors  255.0  2016 - 2019  The mid 2010s Warriors
# 244    Celtics  251.0  1984 - 1987     The mid 80s Celtics
# 608     Lakers  251.0  1985 - 1988      The mid 80s Lakers

# %%
eras = final.drop_duplicates(['Team','Era']).reset_index(drop=True)
eras['Wins/Year'] = eras['Wins'] / 4
eras['Historical Ranking'] = eras['Wins/Year'].map(historical_ranking_classifier)
eras.head(50)
# Out:
#              Team   Wins   Year Range                          Era  Wins/Year  \
# 0        Warriors  265.0  2015 - 2018       The mid 2010s Warriors      66.25
# 1         Celtics  251.0  1984 - 1987          The mid 80s Celtics      62.75
# 2          Lakers  251.0  1985 - 1988           The mid 80s Lakers      62.75
# 3           Bulls  250.0  1995 - 1998            The mid 90s Bulls      62.50
# 4           Bucks  248.0  1971 - 1974          The early 70s Bucks      62.00
# 5          Lakers  247.0  1987 - 1990          The late 80s Lakers      61.75
# 6           Spurs  245.0  2014 - 2017          The mid 2010s Spurs      61.25
# 7           76ers  244.0  1980 - 1983          The early 80s 76ers      61.00
# 8         Celtics  244.0  1982 - 1985        The early 80s Celtics      61.00
# 9     Supersonics  241.0  1994 - 1997      The mid 90s Supersonics      60.25
# 10           Jazz  241.0  1995 - 1998             The mid 90s Jazz      60.25
# 11          Bulls  240.0  1991 - 1994          The early 90s Bulls      60.00
# 12        Celtics  240.0  1972 - 1975        The early 70s Celtics      60.00
# 13          Spurs  239.0  2003 - 2006          The mid 2000s Spurs      59.75
# 14        Celtics  238.0  1973 - 1976          The mid 70s Celtics      59.50
# 15      Mavericks  237.0  2004 - 2007      The mid 2000s Mavericks      59.25
# 16         Lakers  236.0  2008 - 2011        The late 2000s Lakers      59.00
# 17        Celtics  234.0  2008 - 2011       The late 2000s Celtics      58.50
# 18          Spurs  234.0  2002 - 2005        The early 2000s Spurs      58.50
# 19           Suns  232.0  2005 - 2008           The mid 2000s Suns      58.00
# 20         Lakers  231.0  2000 - 2003       The early 2000s Lakers      57.75
# 21         Lakers  231.0  1982 - 1985         The early 80s Lakers      57.75
# 22          Spurs  231.0  2011 - 2014        The early 2010s Spurs      57.75
# 23           Suns  230.0  1992 - 1995           The early 90s Suns      57.50
# 24          Kings  230.0  2001 - 2004        The early 2000s Kings      57.50
# 25  Trail Blazers  230.0  1990 - 1993  The early 90s Trail Blazers      57.50
# 26        Pistons  230.0  2005 - 2008        The mid 2000s Pistons      57.50
# 27          76ers  229.0  1983 - 1986            The mid 80s 76ers      57.25
# 28        Pistons  228.0  1987 - 1990         The late 80s Pistons      57.00
# 29      Mavericks  227.0  2002 - 2005    The early 2000s Mavericks      56.75
# 30          Spurs  225.0  1993 - 1996            The mid 90s Spurs      56.25
# 31        Raptors  224.0  2016 - 2019        The mid 2010s Raptors      56.00
# 32           Heat  224.0  2011 - 2014         The early 2010s Heat      56.00
# 33         Lakers  224.0  1971 - 1974         The early 70s Lakers      56.00
# 34      Mavericks  223.0  2007 - 2010     The late 2000s Mavericks      55.75
# 35          76ers  223.0  1978 - 1981           The late 70s 76ers      55.75
# 36         Knicks  223.0  1992 - 1995         The early 90s Knicks      55.75
# 37      Cavaliers  222.0  2007 - 2010     The late 2000s Cavaliers      55.50
# 38    Supersonics  222.0  1992 - 1995    The early 90s Supersonics      55.50
# 39          Magic  222.0  2008 - 2011         The late 2000s Magic      55.50
# 40       Clippers  222.0  2013 - 2016       The mid 2010s Clippers      55.50
# 41        Thunder  221.0  2011 - 2014      The early 2010s Thunder      55.25
# 42        Raptors  221.0  2017 - 2020       The late 2010s Raptors      55.25
# 43         Lakers  221.0  1989 - 1992         The early 90s Lakers      55.25
# 44          Spurs  221.0  2008 - 2011         The late 2000s Spurs      55.25
# 45        Pistons  220.0  1989 - 1992        The early 90s Pistons      55.00
# 46         Lakers  220.0  2009 - 2012       The early 2010s Lakers      55.00
# 47        Thunder  219.0  2013 - 2016        The mid 2010s Thunder      54.75
# 48         Knicks  219.0  1993 - 1996           The mid 90s Knicks      54.75
# 49           Suns  218.0  1993 - 1996             The mid 90s Suns      54.50
#
#                Historical Ranking
# 0                       Legendary
# 1   Historically Great Contenders
# 2   Historically Great Contenders
# 3   Historically Great Contenders
# 4   Historically Great Contenders
# 5   Historically Great Contenders
# 6   Historically Great Contenders
# 7   Historically Great Contenders
# 8   Historically Great Contenders
# 9   Historically Great Contenders
# 10  Historically Great Contenders
# 11  Historically Great Contenders
# 12  Historically Great Contenders
# 13             Serious contenders
# 14             Serious contenders
# 15             Serious contenders
# 16             Serious contenders
# 17             Serious contenders
# 18             Serious contenders
# 19             Serious contenders
# 20             Serious contenders
# 21             Serious contenders
# 22             Serious contenders
# 23             Serious contenders
# 24             Serious contenders
# 25             Serious contenders
# 26             Serious contenders
# 27             Serious contenders
# 28             Serious contenders
# 29             Serious contenders
# 30             Serious contenders
# 31             Serious contenders
# 32             Serious contenders
# 33             Serious contenders
# 34             Serious contenders
# 35             Serious contenders
# 36             Serious contenders
# 37             Serious contenders
# 38             Serious contenders
# 39             Serious contenders
# 40             Serious contenders
# 41             Serious contenders
# 42             Serious contenders
# 43             Serious contenders
# 44             Serious contenders
# 45             Serious contenders
# 46             Serious contenders
# 47                Good Contenders
# 48                Good Contenders
# 49                Good Contenders

# %%
final.Wins.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
final.drop_duplicates(['Team','Era'],keep='last').sort_values(['Wins']).reset_index(drop=True).head(40)
# Out:
#              Team  Wins   Year Range                           Era
# 0       Grizzlies  56.0  1996 - 1999         The mid 90s Grizzlies
# 1       Grizzlies  63.0  1997 - 2000        The late 90s Grizzlies
# 2           Bulls  66.0  1999 - 2002         The early 2000s Bulls
# 3         Pistons  69.0  2020 - 2023       The early 2020s Pistons
# 4        Clippers  72.0  1998 - 2001         The late 90s Clippers
# 5       Mavericks  74.0  1991 - 1994       The early 90s Mavericks
# 6           76ers  75.0  2014 - 2017           The mid 2010s 76ers
# 7    Timberwolves  75.0  1992 - 1995    The early 90s Timberwolves
# 8       Grizzlies  76.0  1999 - 2002     The early 2000s Grizzlies
# 9        Warriors  76.0  1998 - 2001         The late 90s Warriors
# 10   Timberwolves  78.0  2008 - 2011   The late 2000s Timberwolves
# 11       Warriors  78.0  1999 - 2002      The early 2000s Warriors
# 12       Clippers  80.0  1987 - 1990         The late 80s Clippers
# 13        Nuggets  81.0  1996 - 1999           The mid 90s Nuggets
# 14          Magic  81.0  2020 - 2023         The early 2020s Magic
# 15        Nuggets  81.0  1997 - 2000          The late 90s Nuggets
# 16       Clippers  82.0  1986 - 1989          The mid 80s Clippers
# 17   Timberwolves  82.0  2009 - 2012  The early 2010s Timberwolves
# 18   Timberwolves  86.0  1993 - 1996      The mid 90s Timberwolves
# 19      Mavericks  86.0  1993 - 1996         The mid 90s Mavericks
# 20           Nets  86.0  1987 - 1990             The late 80s Nets
# 21        Rockets  87.0  2020 - 2023       The early 2020s Rockets
# 22           Suns  87.0  2016 - 2019            The mid 2010s Suns
# 23        Wizards  88.0  2009 - 2012       The early 2010s Wizards
# 24          Kings  88.0  2009 - 2012         The early 2010s Kings
# 25          76ers  89.0  1994 - 1997             The mid 90s 76ers
# 26        Raptors  90.0  1996 - 1999           The mid 90s Raptors
# 27         Lakers  91.0  2014 - 2017          The mid 2010s Lakers
# 28       Clippers  91.0  1996 - 1999          The mid 90s Clippers
# 29           Nets  92.0  2009 - 2012          The early 2010s Nets
# 30        Bullets  92.0  1992 - 1995         The early 90s Bullets
# 31       Clippers  94.0  1999 - 2002      The early 2000s Clippers
# 32      Cavaliers  94.0  1981 - 1984       The early 80s Cavaliers
# 33         Pacers  94.0  1983 - 1986            The mid 80s Pacers
# 34           Heat  95.0  1989 - 1992            The early 90s Heat
# 35  Trail Blazers  95.0  1971 - 1974   The early 70s Trail Blazers
# 36        Hornets  96.0  1989 - 1992         The early 90s Hornets
# 37          Hawks  97.0  2004 - 2007           The mid 2000s Hawks
# 38      Cavaliers  97.0  2011 - 2014     The early 2010s Cavaliers
# 39         Knicks  98.0  2017 - 2020         The late 2010s Knicks
