# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
team_names = ['atlanta_hawks','boston_celtics','brooklyn_nets','charlotte_hornets','chicago_bulls',\
              'cleveland_cavaliers','dallas_mavericks','denver_nuggets','detroit_pistons','golden_state_warriors',\
             'houston_rockets','indiana_pacers','los_angeles_clippers','los_angeles_lakers','memphis_grizzlies',\
             'miami_heat','milwaukee_bucks','minnesota_timberwolves','new_york_knicks','oklahoma_city_thunder',\
             'orlando_magic','philadelphia_76ers','phoenix_suns','portland_trailblazers','sacramento_kings',\
             'san_antonio_spurs','toronto_raptors','utah_jazz','washington_wizards']

# %%
df = pd.DataFrame({})
for team in team_names: 
    url = 'https://www.landofbasketball.com/teams/records_' + team + '.htm'
    data = requests.get(url).text
    soup = BeautifulSoup(data, 'html.parser')
    tables = soup.find_all('table')  
    try: 
        temp = pd.read_html(str(tables),skiprows=2)[1]
    except: 
        temp = pd.read_html(str(tables),skiprows=2)[0]
    temp.columns = ['Season','Team','Record','Win%','Standing','Conf','a','b','c']
    temp = temp[['Season','Team','Record']]   
    df = pd.concat([df,temp])

# %%
#Old school teams. 
drop_list = ['Braves','Blackhawks','Zephyrs','Packers']
for drop in drop_list: 
    df = df[df['Team']!=drop]

# %%
df = df.sort_values(['Team','Season']).reset_index(drop=True)
df.head()
# Out:
#     Season   Team Record
# 0  1963-64  76ers  34-46
# 1  1964-65  76ers  40-40
# 2  1965-66  76ers  55-25
# 3  1966-67  76ers  68-13
# 4  1967-68  76ers  62-20

# %%
#Remove this season since it isn't complete! 
df = df[df['Season']!='2022-2023']

# %%
#Coonvert to single number representation (2012-2013 season will be represented as the 2013 season)
temp = df['Season'].str.split('-', expand=True)
temp.columns = ['Season','Year_p2']
temp['Season'] = temp['Season'].astype(int) + 1
temp = temp[['Season']]
df = df.drop(['Season'],axis=1)
df = pd.concat([temp,df],axis=1)
df.head()
# Out:
#    Season   Team Record
# 0    1964  76ers  34-46
# 1    1965  76ers  40-40
# 2    1966  76ers  55-25
# 3    1967  76ers  68-13
# 4    1968  76ers  62-20

# %%
#82 game NBA seasons.
df = df[df['Season'] > 1970]

# %%
#Convert record into just wins since W+L = 82
temp = df['Record'].str.split('-', expand=True)
temp.columns = ['Wins','Loss']
df = pd.concat([df,temp],axis=1)
df = df[['Team','Season','Wins']]
df.head()
# Out:
#      Team  Season Wins
# 7   76ers    1971   47
# 8   76ers    1972   30
# 9   76ers    1973    9
# 10  76ers    1974   25
# 11  76ers    1975   34

# %%
#Compute the rolling sums over 4 year increments. 
df_results = pd.DataFrame(df.groupby('Team')['Wins'].rolling(4).sum()).reset_index().drop(['level_1'],axis=1)
df_results.head()
# Out:
#     Team   Wins
# 0  76ers    NaN
# 1  76ers    NaN
# 2  76ers    NaN
# 3  76ers  111.0
# 4  76ers   98.0

# %%
#Remove the missing data constructed.
df_results = df_results.dropna()
df_results.head()
# Out:
#     Team   Wins
# 3  76ers  111.0
# 4  76ers   98.0
# 5  76ers  114.0
# 6  76ers  155.0
# 7  76ers  185.0

# %%
#Construct the final pandas dataframe. Loop through the teams and update year info. 
final = pd.DataFrame({})
for team in df_results.Team.unique().tolist(): 
    temp = df[df['Team'] == team]
    
    a = temp.Season.min()
    years = []
    era_label = []
    for i in range(temp.shape[0]): 
        r = str(a) + ' - ' + str(a+4-1)
        years.append(r)
        a = a + 1
        if a>=1970 and a<=1973: 
            era_label.append('The early 70s ' + team)
        elif a>=1974 and a<=1977: 
            era_label.append('The mid 70s ' + team)
        elif a>=1978 and a<=1979: 
            era_label.append('The late 70s ' + team)
        elif a>=1980 and a<=1983: 
            era_label.append('The early 80s ' + team)
        elif a>=1984 and a<=1987: 
            era_label.append('The mid 80s ' + team)
        elif a>=1988 and a<=1989: 
            era_label.append('The late 80s ' + team)            
        elif a>=1990 and a<=1993: 
            era_label.append('The early 90s ' + team)
        elif a>=1994 and a<=1997: 
            era_label.append('The mid 90s ' + team)
        elif a>=1998 and a<=1999: 
            era_label.append('The late 90s ' + team)          
        elif a>=2000 and a<=2003: 
            era_label.append('The early 2000s ' + team)
        elif a>=2004 and a<=2007: 
            era_label.append('The mid 2000s ' + team)
        elif a>=2008 and a<=2009: 
            era_label.append('The late 2000s ' + team)  
            
        elif a>=2010 and a<=2013: 
            era_label.append('The early 2010s ' + team)
        elif a>=2014 and a<=2017: 
            era_label.append('The mid 2010s ' + team)
        elif a>=2018 and a<=2019: 
            era_label.append('The late 2010s ' + team) 
        else: 
            era_label.append('The early 2020s ' + team)
        
            
    t = pd.DataFrame({'Year Range':years,'Era':era_label})
    #t = pd.DataFrame([years,era_label],columns = ['Year Range','Era Label'])
    
    temp = df_results[df_results['Team'] == team]
    temp = pd.concat([temp.reset_index(drop=True),t.reset_index(drop=True)],axis=1)
    final = pd.concat([final.reset_index(drop=True),temp.reset_index(drop=True)])

# %%
len(era_label)
# Out:
# 26

# %%
final = final.dropna()
final = final.reset_index(drop=True)
final.head()
# Out:
#     Team   Wins   Year Range                  Era
# 0  76ers  111.0  1971 - 1974  The early 70s 76ers
# 1  76ers   98.0  1972 - 1975  The early 70s 76ers
# 2  76ers  114.0  1973 - 1976    The mid 70s 76ers
# 3  76ers  155.0  1974 - 1977    The mid 70s 76ers
# 4  76ers  185.0  1975 - 1978    The mid 70s 76ers

# %%
final.Wins.hist()
# Out:
# <AxesSubplot:>

# %%
final = final.sort_values(['Wins'],ascending=False).reset_index(drop=True)
final.head(30)
# Out:
#            Team   Wins   Year Range                      Era
# 0      Warriors  265.0  2015 - 2018   The mid 2010s Warriors
# 1      Warriors  258.0  2014 - 2017   The mid 2010s Warriors
# 2      Warriors  255.0  2016 - 2019   The mid 2010s Warriors
# 3       Celtics  251.0  1984 - 1987      The mid 80s Celtics
# 4        Lakers  251.0  1985 - 1988       The mid 80s Lakers
# 5         Bulls  250.0  1995 - 1998        The mid 90s Bulls
# 6       Celtics  248.0  1983 - 1986      The mid 80s Celtics
# 7         Bucks  248.0  1971 - 1974      The early 70s Bucks
# 8        Lakers  247.0  1987 - 1990      The late 80s Lakers
# 9        Lakers  246.0  1986 - 1989       The mid 80s Lakers
# 10      Celtics  246.0  1985 - 1988      The mid 80s Celtics
# 11        Spurs  245.0  2014 - 2017      The mid 2010s Spurs
# 12        76ers  244.0  1980 - 1983      The early 80s 76ers
# 13      Celtics  244.0  1982 - 1985    The early 80s Celtics
# 14       Lakers  243.0  1984 - 1987       The mid 80s Lakers
# 15      Celtics  243.0  1981 - 1984    The early 80s Celtics
# 16        Bulls  243.0  1994 - 1997        The mid 90s Bulls
# 17      Celtics  242.0  1980 - 1983    The early 80s Celtics
# 18        Spurs  242.0  2013 - 2016      The mid 2010s Spurs
# 19  Supersonics  241.0  1994 - 1997  The mid 90s Supersonics
# 20         Jazz  241.0  1995 - 1998         The mid 90s Jazz
# 21        Bulls  240.0  1991 - 1994      The early 90s Bulls
# 22        Bulls  240.0  1990 - 1993      The early 90s Bulls
# 23       Lakers  240.0  1988 - 1991      The late 80s Lakers
# 24      Celtics  240.0  1972 - 1975    The early 70s Celtics
# 25  Supersonics  239.0  1995 - 1998  The mid 90s Supersonics
# 26  Supersonics  239.0  1993 - 1996  The mid 90s Supersonics
# 27        Spurs  239.0  2003 - 2006      The mid 2000s Spurs
# 28      Celtics  238.0  1973 - 1976      The mid 70s Celtics
# 29     Warriors  238.0  2013 - 2016   The mid 2010s Warriors

# %%
era = final.drop_duplicates(['Team','Era']).reset_index(drop=True)
era.head(50)
# Out:
#              Team   Wins   Year Range                          Era
# 0        Warriors  265.0  2015 - 2018       The mid 2010s Warriors
# 1         Celtics  251.0  1984 - 1987          The mid 80s Celtics
# 2          Lakers  251.0  1985 - 1988           The mid 80s Lakers
# 3           Bulls  250.0  1995 - 1998            The mid 90s Bulls
# 4           Bucks  248.0  1971 - 1974          The early 70s Bucks
# 5          Lakers  247.0  1987 - 1990          The late 80s Lakers
# 6           Spurs  245.0  2014 - 2017          The mid 2010s Spurs
# 7           76ers  244.0  1980 - 1983          The early 80s 76ers
# 8         Celtics  244.0  1982 - 1985        The early 80s Celtics
# 9     Supersonics  241.0  1994 - 1997      The mid 90s Supersonics
# 10           Jazz  241.0  1995 - 1998             The mid 90s Jazz
# 11          Bulls  240.0  1991 - 1994          The early 90s Bulls
# 12        Celtics  240.0  1972 - 1975        The early 70s Celtics
# 13          Spurs  239.0  2003 - 2006          The mid 2000s Spurs
# 14        Celtics  238.0  1973 - 1976          The mid 70s Celtics
# 15      Mavericks  237.0  2004 - 2007      The mid 2000s Mavericks
# 16         Lakers  236.0  2008 - 2011        The late 2000s Lakers
# 17        Celtics  234.0  2008 - 2011       The late 2000s Celtics
# 18          Spurs  234.0  2002 - 2005        The early 2000s Spurs
# 19           Suns  232.0  2005 - 2008           The mid 2000s Suns
# 20         Lakers  231.0  2000 - 2003       The early 2000s Lakers
# 21         Lakers  231.0  1982 - 1985         The early 80s Lakers
# 22          Spurs  231.0  2011 - 2014        The early 2010s Spurs
# 23           Suns  230.0  1992 - 1995           The early 90s Suns
# 24          Kings  230.0  2001 - 2004        The early 2000s Kings
# 25  Trail Blazers  230.0  1990 - 1993  The early 90s Trail Blazers
# 26        Pistons  230.0  2005 - 2008        The mid 2000s Pistons
# 27          76ers  229.0  1983 - 1986            The mid 80s 76ers
# 28        Pistons  228.0  1987 - 1990         The late 80s Pistons
# 29      Mavericks  227.0  2002 - 2005    The early 2000s Mavericks
# 30          Spurs  225.0  1993 - 1996            The mid 90s Spurs
# 31        Raptors  224.0  2016 - 2019        The mid 2010s Raptors
# 32           Heat  224.0  2011 - 2014         The early 2010s Heat
# 33         Lakers  224.0  1971 - 1974         The early 70s Lakers
# 34      Mavericks  223.0  2007 - 2010     The late 2000s Mavericks
# 35          76ers  223.0  1978 - 1981           The late 70s 76ers
# 36         Knicks  223.0  1992 - 1995         The early 90s Knicks
# 37      Cavaliers  222.0  2007 - 2010     The late 2000s Cavaliers
# 38    Supersonics  222.0  1992 - 1995    The early 90s Supersonics
# 39          Magic  222.0  2008 - 2011         The late 2000s Magic
# 40       Clippers  222.0  2013 - 2016       The mid 2010s Clippers
# 41        Thunder  221.0  2011 - 2014      The early 2010s Thunder
# 42        Raptors  221.0  2017 - 2020       The late 2010s Raptors
# 43         Lakers  221.0  1989 - 1992         The early 90s Lakers
# 44          Spurs  221.0  2008 - 2011         The late 2000s Spurs
# 45        Pistons  220.0  1989 - 1992        The early 90s Pistons
# 46         Lakers  220.0  2009 - 2012       The early 2010s Lakers
# 47        Thunder  219.0  2013 - 2016        The mid 2010s Thunder
# 48         Knicks  219.0  1993 - 1996           The mid 90s Knicks
# 49           Suns  218.0  1993 - 1996             The mid 90s Suns

# %%
era.Wins.quantile(0.99)
# Out:
# 247.93

# %%
era[era['Team'] == 'Suns']
# Out:
#      Team   Wins   Year Range                   Era
# 19   Suns  232.0  2005 - 2008    The mid 2000s Suns
# 23   Suns  230.0  1992 - 1995    The early 90s Suns
# 49   Suns  218.0  1993 - 1996      The mid 90s Suns
# 55   Suns  216.0  2007 - 2010   The late 2000s Suns
# 66   Suns  211.0  1978 - 1981     The late 70s Suns
# 69   Suns  211.0  1980 - 1983    The early 80s Suns
# 132  Suns  192.0  1988 - 1991     The late 80s Suns
# 153  Suns  187.0  1998 - 2001     The late 90s Suns
# 173  Suns  184.0  2000 - 2003  The early 2000s Suns
# 202  Suns  175.0  1976 - 1979      The mid 70s Suns
# 211  Suns  173.0  2009 - 2012  The early 2010s Suns
# 228  Suns  168.0  2019 - 2022  The early 2020s Suns
# 241  Suns  165.0  1971 - 1974    The early 70s Suns
# 256  Suns  162.0  1983 - 1986      The mid 80s Suns
# 336  Suns  135.0  2013 - 2016    The mid 2010s Suns
# 363  Suns  125.0  2018 - 2021   The late 2010s Suns

# %%
era[era['Team'] == 'Cavaliers']
# Out:
#           Team   Wins   Year Range                        Era
# 37   Cavaliers  222.0  2007 - 2010   The late 2000s Cavaliers
# 67   Cavaliers  211.0  2015 - 2018    The mid 2010s Cavaliers
# 68   Cavaliers  211.0  2006 - 2009    The mid 2000s Cavaliers
# 101  Cavaliers  201.0  1992 - 1995    The early 90s Cavaliers
# 133  Cavaliers  191.0  1993 - 1996      The mid 90s Cavaliers
# 201  Cavaliers  175.0  1975 - 1978      The mid 70s Cavaliers
# 207  Cavaliers  174.0  1988 - 1991     The late 80s Cavaliers
# 232  Cavaliers  167.0  2009 - 2012  The early 2010s Cavaliers
# 266  Cavaliers  159.0  1986 - 1989      The mid 80s Cavaliers
# 278  Cavaliers  153.0  1977 - 1980     The late 70s Cavaliers
# 313  Cavaliers  143.0  1997 - 2000     The late 90s Cavaliers
# 327  Cavaliers  139.0  2017 - 2020   The late 2010s Cavaliers
# 365  Cavaliers  124.0  1972 - 1975    The early 70s Cavaliers
# 367  Cavaliers  123.0  2002 - 2005  The early 2000s Cavaliers
# 388  Cavaliers  110.0  1979 - 1982    The early 80s Cavaliers
# 394  Cavaliers  104.0  2019 - 2022  The early 2020s Cavaliers

# %%
era.Wins.quantile(0.85)
# Out:
# 213.0

# %%
final.Wins.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
final.drop_duplicates(['Team','Era'],keep='last').sort_values(['Wins']).reset_index(drop=True).head(40)
# Out:
#              Team  Wins   Year Range                           Era
# 0       Grizzlies  56.0  1996 - 1999         The mid 90s Grizzlies
# 1       Grizzlies  63.0  1997 - 2000        The late 90s Grizzlies
# 2           Bulls  66.0  1999 - 2002         The early 2000s Bulls
# 3         Pistons  69.0  2020 - 2023       The early 2020s Pistons
# 4        Clippers  72.0  1998 - 2001         The late 90s Clippers
# 5       Mavericks  74.0  1991 - 1994       The early 90s Mavericks
# 6           76ers  75.0  2014 - 2017           The mid 2010s 76ers
# 7    Timberwolves  75.0  1992 - 1995    The early 90s Timberwolves
# 8        Warriors  76.0  1998 - 2001         The late 90s Warriors
# 9       Grizzlies  76.0  1999 - 2002     The early 2000s Grizzlies
# 10   Timberwolves  78.0  2008 - 2011   The late 2000s Timberwolves
# 11       Warriors  78.0  1999 - 2002      The early 2000s Warriors
# 12       Clippers  80.0  1987 - 1990         The late 80s Clippers
# 13          Magic  81.0  2020 - 2023         The early 2020s Magic
# 14        Nuggets  81.0  1996 - 1999           The mid 90s Nuggets
# 15        Nuggets  81.0  1997 - 2000          The late 90s Nuggets
# 16       Clippers  82.0  1986 - 1989          The mid 80s Clippers
# 17   Timberwolves  82.0  2009 - 2012  The early 2010s Timberwolves
# 18   Timberwolves  86.0  1993 - 1996      The mid 90s Timberwolves
# 19           Nets  86.0  1987 - 1990             The late 80s Nets
# 20      Mavericks  86.0  1993 - 1996         The mid 90s Mavericks
# 21        Rockets  87.0  2020 - 2023       The early 2020s Rockets
# 22           Suns  87.0  2016 - 2019            The mid 2010s Suns
# 23          Kings  88.0  2009 - 2012         The early 2010s Kings
# 24        Wizards  88.0  2009 - 2012       The early 2010s Wizards
# 25          76ers  89.0  1994 - 1997             The mid 90s 76ers
# 26        Raptors  90.0  1996 - 1999           The mid 90s Raptors
# 27         Lakers  91.0  2014 - 2017          The mid 2010s Lakers
# 28       Clippers  91.0  1996 - 1999          The mid 90s Clippers
# 29           Nets  92.0  2009 - 2012          The early 2010s Nets
# 30        Bullets  92.0  1992 - 1995         The early 90s Bullets
# 31         Pacers  94.0  1983 - 1986            The mid 80s Pacers
# 32      Cavaliers  94.0  1981 - 1984       The early 80s Cavaliers
# 33       Clippers  94.0  1999 - 2002      The early 2000s Clippers
# 34           Heat  95.0  1989 - 1992            The early 90s Heat
# 35  Trail Blazers  95.0  1971 - 1974   The early 70s Trail Blazers
# 36        Hornets  96.0  1989 - 1992         The early 90s Hornets
# 37      Cavaliers  97.0  2011 - 2014     The early 2010s Cavaliers
# 38          Hawks  97.0  2004 - 2007           The mid 2000s Hawks
# 39           Suns  98.0  2017 - 2020           The late 2010s Suns

# %%
final.sort_values(['Wins'],ascending=False).tail(30)
# Out:
#               Team  Wins   Year Range                           Era
# 1237          Suns  87.0  2016 - 2019            The mid 2010s Suns
# 1238       Rockets  87.0  2020 - 2023       The early 2020s Rockets
# 1239          Nets  86.0  1987 - 1990             The late 80s Nets
# 1240  Timberwolves  86.0  1993 - 1996      The mid 90s Timberwolves
# 1241     Mavericks  86.0  1993 - 1996         The mid 90s Mavericks
# 1242  Timberwolves  85.0  1990 - 1993    The early 90s Timberwolves
# 1243         Bulls  83.0  2000 - 2003         The early 2000s Bulls
# 1244  Timberwolves  83.0  1991 - 1994    The early 90s Timberwolves
# 1245      Clippers  82.0  1986 - 1989          The mid 80s Clippers
# 1246     Mavericks  82.0  1992 - 1995       The early 90s Mavericks
# 1247  Timberwolves  82.0  2009 - 2012  The early 2010s Timberwolves
# 1250       Nuggets  81.0  1996 - 1999           The mid 90s Nuggets
# 1251         Magic  81.0  2020 - 2023         The early 2020s Magic
# 1249         76ers  81.0  2013 - 2016           The mid 2010s 76ers
# 1248       Nuggets  81.0  1997 - 2000          The late 90s Nuggets
# 1252      Clippers  80.0  1987 - 1990         The late 80s Clippers
# 1253      Warriors  78.0  1999 - 2002      The early 2000s Warriors
# 1254  Timberwolves  78.0  2008 - 2011   The late 2000s Timberwolves
# 1255      Clippers  77.0  1997 - 2000         The late 90s Clippers
# 1256      Warriors  76.0  1998 - 2001         The late 90s Warriors
# 1257     Grizzlies  76.0  1999 - 2002     The early 2000s Grizzlies
# 1258         76ers  75.0  2014 - 2017           The mid 2010s 76ers
# 1259  Timberwolves  75.0  1992 - 1995    The early 90s Timberwolves
# 1260     Mavericks  74.0  1991 - 1994       The early 90s Mavericks
# 1261     Grizzlies  72.0  1998 - 2001        The late 90s Grizzlies
# 1262      Clippers  72.0  1998 - 2001         The late 90s Clippers
# 1263       Pistons  69.0  2020 - 2023       The early 2020s Pistons
# 1264         Bulls  66.0  1999 - 2002         The early 2000s Bulls
# 1265     Grizzlies  63.0  1997 - 2000        The late 90s Grizzlies
# 1266     Grizzlies  56.0  1996 - 1999         The mid 90s Grizzlies

# %%
final[final['Team'] == 'Cavaliers'].sort_values(['Wins'])
# Out:
#            Team   Wins   Year Range                        Era
# 1219  Cavaliers   94.0  1981 - 1984    The early 80s Cavaliers
# 1211  Cavaliers   97.0  2011 - 2014  The early 2010s Cavaliers
# 1198  Cavaliers   99.0  1971 - 1974    The early 70s Cavaliers
# 1194  Cavaliers  100.0  2020 - 2023  The early 2020s Cavaliers
# 1191  Cavaliers  102.0  1982 - 1985    The early 80s Cavaliers
# 1178  Cavaliers  103.0  1980 - 1983    The early 80s Cavaliers
# 1173  Cavaliers  104.0  2019 - 2022  The early 2020s Cavaliers
# 1139  Cavaliers  108.0  2000 - 2003  The early 2000s Cavaliers
# 1126  Cavaliers  110.0  2018 - 2021   The late 2010s Cavaliers
# 1125  Cavaliers  110.0  1979 - 1982    The early 80s Cavaliers
# 1122  Cavaliers  111.0  2001 - 2004  The early 2000s Cavaliers
# 1107  Cavaliers  113.0  1999 - 2002  The early 2000s Cavaliers
# 1077  Cavaliers  116.0  1983 - 1986      The mid 80s Cavaliers
# 1030  Cavaliers  123.0  2002 - 2005  The early 2000s Cavaliers
# 1020  Cavaliers  124.0  1984 - 1987      The mid 80s Cavaliers
# 1022  Cavaliers  124.0  1972 - 1975    The early 70s Cavaliers
# 1014  Cavaliers  125.0  2010 - 2013  The early 2010s Cavaliers
# 969   Cavaliers  131.0  1998 - 2001     The late 90s Cavaliers
# 965   Cavaliers  131.0  2012 - 2015  The early 2010s Cavaliers
# 911   Cavaliers  138.0  1978 - 1981     The late 70s Cavaliers
# 903   Cavaliers  138.0  1985 - 1988      The mid 80s Cavaliers
# 892   Cavaliers  139.0  2017 - 2020   The late 2010s Cavaliers
# 847   Cavaliers  143.0  1997 - 2000     The late 90s Cavaliers
# 839   Cavaliers  144.0  2003 - 2006    The mid 2000s Cavaliers
# 774   Cavaliers  150.0  1973 - 1976      The mid 70s Cavaliers
# 744   Cavaliers  153.0  1977 - 1980     The late 70s Cavaliers
# 693   Cavaliers  158.0  1996 - 1999      The mid 90s Cavaliers
# 685   Cavaliers  159.0  1986 - 1989      The mid 80s Cavaliers
# 653   Cavaliers  161.0  1974 - 1977      The mid 70s Cavaliers
# 610   Cavaliers  165.0  1976 - 1979      The mid 70s Cavaliers
# 572   Cavaliers  167.0  2013 - 2016    The mid 2010s Cavaliers
# 570   Cavaliers  167.0  2009 - 2012  The early 2010s Cavaliers
# 519   Cavaliers  172.0  1987 - 1990     The late 80s Cavaliers
# 495   Cavaliers  174.0  1988 - 1991     The late 80s Cavaliers
# 483   Cavaliers  175.0  1975 - 1978      The mid 70s Cavaliers
# 464   Cavaliers  177.0  2004 - 2007    The mid 2000s Cavaliers
# 455   Cavaliers  177.0  2016 - 2019    The mid 2010s Cavaliers
# 436   Cavaliers  179.0  1994 - 1997      The mid 90s Cavaliers
# 441   Cavaliers  179.0  1995 - 1998      The mid 90s Cavaliers
# 367   Cavaliers  186.0  1990 - 1993    The early 90s Cavaliers
# 341   Cavaliers  187.0  2005 - 2008    The mid 2000s Cavaliers
# 321   Cavaliers  189.0  1989 - 1992    The early 90s Cavaliers
# 298   Cavaliers  191.0  2008 - 2011   The late 2000s Cavaliers
# 296   Cavaliers  191.0  1993 - 1996      The mid 90s Cavaliers
# 295   Cavaliers  191.0  1991 - 1994    The early 90s Cavaliers
# 273   Cavaliers  194.0  2014 - 2017    The mid 2010s Cavaliers
# 217   Cavaliers  201.0  1992 - 1995    The early 90s Cavaliers
# 146   Cavaliers  211.0  2006 - 2009    The mid 2000s Cavaliers
# 144   Cavaliers  211.0  2015 - 2018    The mid 2010s Cavaliers
# 81    Cavaliers  222.0  2007 - 2010   The late 2000s Cavaliers
